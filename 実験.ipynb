# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ['Recording timestamp', 'Presented Stimulus name', 'AOI hit [1 - 下広告]', 'AOI hit [1 - 上広告]', 'AOI hit [1 - 文章]']

# %%
pattern_df = pd.read_excel('drive/MyDrive/実験/data/組合せ.xlsx')
pattern_num = 1

# %%
def pick_data(df):
  return None
# Out:
#   File "<ipython-input-4-d66e7d23e051>", line 2
#
#     ^
# SyntaxError: incomplete input

# %%
df1 = pd.read_excel('drive/MyDrive/実験/data/1.xlsx')
df2 = pd.read_excel('drive/MyDrive/実験/data/2.xlsx')
df3 = pd.read_excel('drive/MyDrive/実験/data/3.xlsx')
df4 = pd.read_excel('drive/MyDrive/実験/data/4.xlsx')
df5 = pd.read_excel('drive/MyDrive/実験/data/5.xlsx')
df6 = pd.read_excel('drive/MyDrive/実験/data/6.xlsx')
df7 = pd.read_excel('drive/MyDrive/実験/data/7.xlsx')
df8 = pd.read_excel('drive/MyDrive/実験/data/8.xlsx')
df9 = pd.read_excel('drive/MyDrive/実験/data/9.xlsx')
df10 = pd.read_excel('drive/MyDrive/実験/data/10.xlsx')
df11 = pd.read_excel('drive/MyDrive/実験/data/11.xlsx')
df12 = pd.read_excel('drive/MyDrive/実験/data/12.xlsx')

# %%
def pick_data(df, pattern_num):
  df = df[['Recording timestamp', 'Presented Stimulus name', 'AOI hit [1 - 下広告]', 'AOI hit [1 - 上広告]', 'AOI hit [1 - 文章]']]
  data = df.copy()
  data = data.rename(columns={'Recording timestamp':'time_stamp',
                    'Presented Stimulus name':'作業',
                    'AOI hit [1 - 下広告]':'up',
                    'AOI hit [1 - 上広告]':'down',
                    'AOI hit [1 - 文章]':'text'})
  data['time'] = data['time_stamp'] / 1_000_000
  data = data.query('作業==@pattern_num')
  data['time'] = data['time'] - np.min(data['time'])
  data['up'] = data['up'].apply(lambda x: 1 if x==1 else 0)
  data['down'] = data['down'].apply(lambda x: 1 if x==1 else 0)
  data['text'] = data['text'].apply(lambda x: 1 if x==1 else 0)
  data = data.drop(['time_stamp', '作業'], axis=1)
  slide_num = 7
  DF = pd.DataFrame([])
  for i in range(slide_num):
    min_time = 5 + 25*i
    max_time = 25*(i+1)
    tmp = data.query('@min_time <= time <= @max_time')
    tmp['slide_num'] = i + 1
    DF = pd.concat([DF, tmp])

  data = DF
  data = pd.merge(data, pattern_df[[pattern_num, '番号']], left_on='slide_num', right_on=1)
  data = data.drop(['slide_num'], axis=1)
  data = data.query('up==1 | down==1 | text==1')
  group_data = data.groupby('番号').agg({'up': 'sum',
                                      'down':'sum',
                                      'text': 'sum'}).reset_index()
  return group_data

# %%
data1
# Out:
#    番号   up  down  text
# 0   1  263     0   163
# 1   2    0     0   728
# 2   3    0     0   700
# 3   4    0     0   839
# 4   5    0    38   906
# 5   6   53    91   638
# 6   7    0     0   924
